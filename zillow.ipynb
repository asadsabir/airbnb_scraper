# %%
import pandas as pd
import seaborn as sb

# %%
bnbs = pd.read_csv('airbnb.csv',index_col=[0])
bnbs.head()
# Out:
#                                                title  guests  bedrooms  beds  \
# 0                 Hot Tub, Putting Green, Game Room!      10         3     4
# 1  Cheerful 4 bedrooms vacation home near Bishop ...      12         4     6
# 2        ★Amazing Backyard★ 5min walk to Restaurants      10         3     5
# 3  Stylish & Comfy ~ Mins to AT&T ~ ♛Royal Beds ~...      12         5     6
# 4             Cozy 2 story house, 5 bedrooms, 8 beds      12         5     8
#
#    bathrooms  price  days booked  Superhost       location  rating  reviews  \
# 0          2    237           51       True     Carrollton    5.00       28
# 1          2    285           32       True         Dallas    5.00        4
# 2          2    192          155      False         Dallas    4.77      186
# 3          0    250           90      False  Grand Prairie    5.00        6
# 4          0    339            3      False         Frisco    4.90       10
#
#     place type  State
# 0  Entire home  Texas
# ...

# %%
bnbs = pd.read_csv('properties.csv',index_col=[0])
bnbs.head()
# Out:
#                                              address  \
# 0  {'streetAddress': '1065 2nd Ave', 'city': 'New...
#
#                                          description  \
# 0  Inspired by Alvar Aaltos iconic vase, Aalto57s...
#
#                                               photos  zipcode         phone  \
# 0  ['https://photos.zillowstatic.com/fp/0c1099a18...    10022  646-681-3805
#
#       name                                        floor_plans
# 0  Aalto57  [{'zpid': '2062374520', '__typename': 'FloorPl...

# %%
bnbs = pd.read_csv('rentals.csv',index_col=[0])
bnbs.head()
# Out:
#              buildingId         lotId       price  \
# 0  32.995792--96.672485  1.001413e+09  $1,371+/mo
# 1  32.999767--96.700516  2.198275e+09  $1,620+/mo
# 2   32.934216--96.72765  2.175003e+09  $1,479+/mo
# 3   32.933865--96.73186  2.566621e+09  $1,706+/mo
# 4   33.001316--96.64173  1.001413e+09  $1,389+/mo
#
#                                             latLong  minBeds  minBaths  \
# 0  {'latitude': 32.995792, 'longitude': -96.672485}      1.0       1.0
# 1  {'latitude': 32.999767, 'longitude': -96.700516}      1.0       1.0
# 2   {'latitude': 32.934216, 'longitude': -96.72765}      1.0       1.0
# 3   {'latitude': 32.933865, 'longitude': -96.73186}      0.0       0.0
# 4   {'latitude': 33.001316, 'longitude': -96.64173}      1.0       1.0
#
#    minArea                                             imgSrc hasImage  \
# 0    712.0  https://photos.zillowstatic.com/fp/2560654cb1f...     True
# 1    605.0  https://photos.zillowstatic.com/fp/38403f447c8...     True
# ...

# %%
bnbs = pd.read_csv('sales.csv',index_col=[0])
bnbs.head()
# Out:
#           zpid     price priceLabel  beds  baths    area  \
# 0   27169584.0  $425,000      $425K   4.0    2.0  1824.0
# 1  168643357.0  $595,000      $595K   4.0    4.0  2930.0
# 2   27177054.0  $400,000      $400K   4.0    2.0  2120.0
# 3   27171098.0  $280,000      $280K   3.0    2.0  1210.0
# 4   80228944.0  $365,000      $365K   2.0    3.0  1835.0
#
#                                            latLong statusType  \
# 0  {'latitude': 32.949646, 'longitude': -96.74219}   FOR_SALE
# 1  {'latitude': 33.000977, 'longitude': -96.62158}   FOR_SALE
# 2  {'latitude': 32.93572, 'longitude': -96.701904}   FOR_SALE
# 3   {'latitude': 32.95005, 'longitude': -96.76234}   FOR_SALE
# 4    {'latitude': 32.94717, 'longitude': -96.7178}   FOR_SALE
#
#            statusText isFavorite  ... minArea unitCount isBuilding badgeInfo  \
# 0      House for sale      False  ...     NaN       NaN        NaN       NaN
# 1      House for sale      False  ...     NaN       NaN        NaN       NaN
# ...
